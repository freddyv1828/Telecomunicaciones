# %%
import funciones

# %% [markdown]
# # EXtracción de los conjuntos de datos

# %% [markdown]
# Data Internet

# %% [markdown]
# A continuación se realizara la extracion a travez de la API de ENACOM, correspondientes a la data nacional de accesos a internet fijo, banda ancha

# %%
url4= "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/TOTAL-NACIO-DE-ACCES-48866/data.csv/?auth_key=izIDjhitsUg8xNsiismBEDYpsisF2rwPxc2ZzRrb"
df_total_nacional_acces_internet= funciones.extraer_caonjunto(url4)
df_total_nacional_acces_internet.head()
# Out:
#     Año  Trimestre  Banda ancha fija  Dial up  Total        Periodo
# 0  2022          4                11       12     11   Oct-Dic 2022
# 1  2022          3                11       12     11  Jul-Sept 2022
# 2  2022          2                11       12     11   Abr-Jun 2022
# 3  2022          1                11       13     11   Ene-Mar 2022
# 4  2021          4                10       13     10   Oct-Dic 2021

# %% [markdown]
# Obtenemos el dataframe

# %% [markdown]
# Se procede a cargar el dataset, para luego la realización de su respectivo ETL

# %%
df_total_nacional_acces_internet.to_parquet("../Data/Internet/Nacional/nacional_acces_inter.parquet")

# %% [markdown]
# Se procede a la extracion del dataset, de penetracion por hogares de internet fijo a nivel nacional

# %%
url_acces_ba_bang_provin = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/BANDA-ANCHA-Y-BANDA-ANGOS/data.csv/?auth_key=9cun92xcuW7JGFfRreeHvM0expDhKp0w8OXd7h6q"
df_acces_provin_bandas = funciones.extraer_caonjunto(url_acces_ba_bang_provin)
df_acces_provin_bandas.head()
# Out:
#     Año  Trimestre        Provincia  Banda ancha fija  Dial up  Total
# 0  2022          4     Buenos Aires                 5      6.0      5
# 1  2022          4  Capital Federal                 2      2.0      2
# 2  2022          4        Catamarca                71      1.0     71
# 3  2022          4            Chaco               144      5.0    144
# 4  2022          4           Chubut               168    904.0    169

# %% [markdown]
# Cargamos el dataset

# %%
df_acces_provin_bandas.to_parquet("../Data/Internet/Provincia/acces_provin_bandas.parquet")

# %% [markdown]
# Acceso a internet por tecnologia en las diferentes provincias

# %%
url_tec_provin = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/ACCES-A-INTER-FIJO-POR/data.csv/?auth_key=9cun92xcuW7JGFfRreeHvM0expDhKp0w8OXd7h6q"
df_acces_tec_provin = funciones.extraer_caonjunto(url_tec_provin)
df_acces_tec_provin
# Out:
#       Año                                          Trimestre  \
# 0    2022                                                  4
# 1    2022                                                  4
# 2    2022                                                  4
# 3    2022                                                  4
# 4    2022                                                  4
# ..    ...                                                ...
# 860  2014                                                  1
# 861  2014                                                  1
# 862  2014                                                  1
# 863  2014                                                  1
# 864     *  Los datos provinciales no coinciden a nivel na...
#
#                Provincia   ADSL  Cablemodem  Fibra óptica  Wireless  Otros  \
# 0           Buenos Aires  326.0         3.0           1.0     130.0   72.0
# 1        Capital Federal  139.0         1.0         139.0       5.0   32.0
# ...

# %% [markdown]
# Carga de datos

# %%
df_acces_tec_provin.to_parquet("../Data/Internet/Provincia/acces_tec_provin.parquet")

# %% [markdown]
# Se extrae el dataset, de velocidad media de baja por provincia

# %%
vel_med_donw_provin = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/VELOC-PROME-DE-BAJAD-DE/data.csv/?auth_key=9cun92xcuW7JGFfRreeHvM0expDhKp0w8OXd7h6q"
df_vel_med_donw_provin = funciones.extraer_caonjunto(vel_med_donw_provin)
df_vel_med_donw_provin
# Out:
#       Año  Trimestre            Provincia  Mbps (Media de bajada)
# 0    2022          4         Buenos Aires                 111.000
# 1    2022          4      Capital Federal                  18.286
# 2    2022          4            Catamarca                   8.333
# 3    2022          4                Chaco                  10.402
# 4    2022          4               Chubut                   1.592
# ..    ...        ...                  ...                     ...
# 859  2014          1           Santa Cruz                 332.000
# 860  2014          1             Santa Fe                 315.000
# 861  2014          1  Santiago Del Estero                 295.000
# 862  2014          1     Tierra Del Fuego                 345.000
# 863  2014          1              Tucumán                 321.000
#
# [864 rows x 4 columns]

# %% [markdown]
# Carga de los datos

# %%
df_vel_med_donw_provin.to_parquet("../Data/Internet/Provincia/velo_medi_bajada.parquet")

# %% [markdown]
# Dataset de acceso a internet fijo por velocidad de bajada para localidades

# %%
acce_localidad = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/ACCES-A-INTER-FIJO-16249/data.csv/?auth_key=9cun92xcuW7JGFfRreeHvM0expDhKp0w8OXd7h6q"
df_acce_localidad = funciones.extraer_caonjunto(acce_localidad)
df_acce_localidad
# Out:
#          Provincia      Partido                           Localidad  \
# 0     BUENOS AIRES   25 de Mayo                          25 de Mayo
# 1     BUENOS AIRES   25 de Mayo                     Agustín Mosconi
# 2     BUENOS AIRES   25 de Mayo                           Del Valle
# 3     BUENOS AIRES   25 de Mayo                           Ernestina
# 4     BUENOS AIRES   25 de Mayo                   Gobernador Ugarte
# ...            ...          ...                                 ...
# 3090       TUCUMAN   Tafí Viejo  Villa Mariano Moreno - El Colmenar
# 3091       TUCUMAN      Trancas                San Pedro de Colalao
# 3092       TUCUMAN      Trancas                   Villa  de Trancas
# 3093       TUCUMAN  Yerba Buena                       Villa Carmela
# 3094       TUCUMAN  Yerba Buena            Yerba Buena - Marcos Paz
#
#      Link Indec  Otros  0,256 Mbps  0,375 Mbps  0,5 Mbps  0,512 Mbps  \
# 0       6854100    NaN         NaN         NaN       2.0         NaN
# ...

# %%
df_acce_localidad.to_parquet("../Data/Internet/Localidad/acceso_localidad.parquet")

# %% [markdown]
# Acceso a internet por tecnologia y provincia

# %%
acc_tec_loc = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/ACCES-A-INTER-FIJO-62463/data.csv/?auth_key=9cun92xcuW7JGFfRreeHvM0expDhKp0w8OXd7h6q"
df_acc_tec_loc = funciones.extraer_caonjunto(acc_tec_loc)
df_acc_tec_loc
# Out:
#          Provincia      Partido                           Localidad  \
# 0     BUENOS AIRES   25 de Mayo                          25 de Mayo
# 1     BUENOS AIRES   25 de Mayo                           Del Valle
# 2     BUENOS AIRES   25 de Mayo                   Gobernador Ugarte
# 3     BUENOS AIRES   25 de Mayo              Norberto de la Riestra
# 4     BUENOS AIRES   25 de Mayo                    Lucas Monteverde
# ...            ...          ...                                 ...
# 3132       TUCUMAN   Tafí Viejo  Villa Mariano Moreno - El Colmenar
# 3133       TUCUMAN      Trancas                San Pedro de Colalao
# 3134       TUCUMAN      Trancas                   Villa  de Trancas
# 3135       TUCUMAN  Yerba Buena                       Villa Carmela
# 3136       TUCUMAN  Yerba Buena            Yerba Buena - Marcos Paz
#
#      Link Indec ADSL CABLEMODEM DIAL UP FIBRA OPTICA OTROS SATELITAL WIMAX  \
# ...

# %%
df_acc_tec_loc.to_parquet("../Data/Internet/Localidad/acceso_tecno_localidad.parquet")

# %% [markdown]
# Localidades con conectividad a internet

# %%
loc_conec_internet = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/LISTA-DE-LOCAL-CON-CONEC/data.csv/?auth_key=9cun92xcuW7JGFfRreeHvM0expDhKp0w8OXd7h6q"
df_loc_conec_internet = funciones.extraer_caonjunto(loc_conec_internet)
df_loc_conec_internet
# Out:
#          Provincia     Partido                                Localidad ADSL  \
# 0     BUENOS AIRES  9 de Julio  Alfredo Demarchi (Est. Facundo Quiroga)   SI
# 1     BUENOS AIRES  9 de Julio                        Carlos María Naón   --
# 2     BUENOS AIRES  9 de Julio                                 Dudignac   --
# 3     BUENOS AIRES  9 de Julio                 La Aurora (Est. La Niña)   --
# 4     BUENOS AIRES  9 de Julio           Manuel B. Gonnet (Est. French)   SI
# ...            ...         ...                                      ...  ...
# 4306  BUENOS AIRES       Pilar                                    Pilar   SI
# 4307  BUENOS AIRES       Pilar                        Presidente Derqui   SI
# 4308  BUENOS AIRES       Pilar                       Roberto De Vicenzo   --
# 4309  BUENOS AIRES       Pilar                             Santa Teresa   --
# 4310  BUENOS AIRES       Pilar                              Tortuguitas   --
#
# ...

# %% [markdown]
# carga de dataset

# %%
df_loc_conec_internet.to_parquet("../Data/Internet/Localidad/localidades_conexion_internet.parquet")

# %% [markdown]
# Ingresos por la operacion de servicios de internet fijo

# %%
ingresos_internet = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/INGRE-POR-LA-OPERA-DEL/data.csv/?auth_key=9cun92xcuW7JGFfRreeHvM0expDhKp0w8OXd7h6q"
df_ingresos_internet = funciones.extraer_caonjunto(ingresos_internet)
df_ingresos_internet
# Out:
#      Año  Trimestre  Ingresos (miles de pesos)        Periodo
# 0   2022          4                         72   Oct-Dic 2022
# 1   2022          3                         64  Jul-Sept 2022
# 2   2022          2                         60   Abr-Jun 2022
# 3   2022          1                         55   Ene-Mar 2022
# 4   2021          4                         45   Oct-Dic 2021
# 5   2021          3                         43  Jul-Sept 2021
# 6   2021          2                         38   Abr-Jun 2021
# 7   2021          1                         37   Ene-Mar 2021
# 8   2020          4                         34   Oct-Dic 2020
# 9   2020          3                         32  Jul-Sept 2020
# 10  2020          2                         32   Abr-Jun 2020
# 11  2020          1                         30   Ene-Mar 2020
# 12  2019          4                         24   Oct-Dic 2019
# 13  2019          3                         22  Jul-Sept 2019
# ...

# %% [markdown]
# Cargar dataset

# %%
df_ingresos_internet.to_parquet("../Data/Internet/Nacional/ingresos_operacion_internet.parquet")

# %% [markdown]
# Telefonia Movil

# %% [markdown]
# Cargueremos un conjunto de datos que representa los ingresos a por el servicio prestados de telefonia mmovil

# %%
ingresos_tel_movil = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/INGRE-TRIME-POR-LA-PREST/data.csv/?auth_key=9cun92xcuW7JGFfRreeHvM0expDhKp0w8OXd7h6q"
df_ingresos_tel_movil = funciones.extraer_caonjunto(ingresos_tel_movil)
df_ingresos_tel_movil
# Out:
#      Año  Trimestre Ingresos (miles de $)        Periodo
# 0   2013          1          $ 13.135.235   Ene-Mar 2013
# 1   2013          2          $ 13.970.806   Abr-Jun 2013
# 2   2013          3          $ 15.235.659  Jul-Sept 2013
# 3   2013          4          $ 16.218.846   Oct-Dic 2013
# 4   2014          1          $ 15.938.353   Ene-Mar 2013
# 5   2014          2          $ 17.680.972   Abr-Jun 2014
# 6   2014          3          $ 18.976.053  Jul-Sept 2014
# 7   2014          4          $ 20.012.332   Oct-Dic 2014
# 8   2015          1          $ 19.337.342   Ene-Mar 2015
# 9   2015          2          $ 19.945.453   Abr-Jun 2015
# 10  2015          3          $ 21.785.238  Jul-Sept 2015
# 11  2015          4          $ 24.881.967   Oct-Dic 2015
# 12  2016          1          $ 24.763.052   Ene-Mar 2016
# 13  2016          2          $ 25.353.971   Abr-Jun 2016
# 14  2016          3          $ 27.416.177  Jul-Sept 2016
# ...

# %% [markdown]
# Carga del dataset

# %%
df_ingresos_tel_movil.to_parquet("../Data/Telefonia_movil/Nacional/ingresos_tel_movil.parquet")

# %% [markdown]
# Extraemos un conjunto de datos correspondiente al total acceso nacional en telefonia movil

# %%
total_acceso_tel_movil = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/TOTAL-NACIO-DE-ACCES-52199/data.csv/?auth_key=9cun92xcuW7JGFfRreeHvM0expDhKp0w8OXd7h6q"
df_total_acceso_tel_movil = funciones.extraer_caonjunto(total_acceso_tel_movil)
df_total_acceso_tel_movil
# Out:
#      Año  Trimestre Total de accesos pospago Total de accesos prepago  \
# 0   2013          1                7.761.349               57.147.608
# 1   2013          2                7.769.110               58.004.822
# 2   2013          3                8.002.183               59.048.909
# 3   2013          4                8.674.516               58.894.516
# 4   2014          1                8.224.482               54.725.089
# 5   2014          2                7.953.775               53.009.865
# 6   2014          3                8.214.424               53.102.043
# 7   2014          4                8.027.505               53.093.330
# 8   2015          1                7.747.230               52.474.633
# 9   2015          2                7.633.527               52.241.939
# 10  2015          3                7.600.799               53.131.712
# 11  2015          4                7.594.526               54.247.485
# ...

# %% [markdown]
# Cargamos el dataset

# %%
df_total_acceso_tel_movil.to_parquet("../Data/Telefonia_movil/Nacional/total_acceso_tel_movil.parquet")

# %% [markdown]
# Extraccion dataset de portabilidad nuemrica movil, que contribuye a las portaciones netas mensualmente por operador

# %%
portabilidad_neta_ensual = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/PORTA-NUMER-MOVIL-ALTAS-Y/data.csv/?auth_key=9cun92xcuW7JGFfRreeHvM0expDhKp0w8OXd7h6q"
df_portabilidad_neta_ensual= funciones.extraer_caonjunto(portabilidad_neta_ensual)
df_portabilidad_neta_ensual
# Out:
#       Año  Mes  Personal  Claro  Nextel  Movistar  Otros
# 0    2012    3       -17     19       0        -2      0
# 1    2012    4         4     -1    -189        -2      0
# 2    2012    5         1      5    -853        -5      0
# 3    2012    6         3     -1    -848        -1      0
# 4    2012    7         6     -4      -1      -602      0
# ..    ...  ...       ...    ...     ...       ...    ...
# 125  2022    8       996     20       0       -21     41
# 126  2022    9        -2     18       0       -16    141
# 127  2022   10        -2    987       0       469    149
# 128  2022   11       788      8       0        -9    233
# 129  2022   12        -2      8       0        -6    217
#
# [130 rows x 7 columns]

# %% [markdown]
# Carga de dataset

# %%
df_portabilidad_neta_ensual.to_parquet("../Data/Telefonia_movil/Nacional/portabili_neta_mensual.parquet")

# %% [markdown]
# Telefonia fija

# %% [markdown]
# Se extraera el conjunto de datos que representa los ingresos por servicio de telefonia fija a nivel nacional

# %%
ingresos_trim_tele_fija = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/INGRE-TRIME-POR-LA-96059/data.csv/?auth_key=L0hKPyjaBMIJS46l2RPRLaSr6qz7i3EXqwCXTWrq"
df_ingresos_trim_tele_fija = funciones.extraer_caonjunto(ingresos_trim_tele_fija)
df_ingresos_trim_tele_fija
# Out:
#      Año  Trimestre Ingresos (miles de $)
# 0   2014          1           291.607.175
# 1   2014          2           297.486.520
# 2   2014          3           310.546.202
# 3   2014          4           333.969.090
# 4   2015          1           326.012.475
# 5   2015          2           342.551.848
# 6   2015          3           359.088.318
# 7   2015          4           381.536.412
# 8   2016          1           419.826.039
# 9   2016          2           471.876.982
# 10  2016          3           495.196.766
# 11  2016          4           496.459.639
# 12  2017          1           637.568.176
# 13  2017          2           697.061.722
# 14  2017          3           666.794.353
# 15  2017          4           551.433.619
# 16  2018          1           825.227.999
# 17  2018          2           791.172.307
# 18  2018          3         1.011.135.057
# 19  2018          4           899.715.788
# 20  2019          1         1.223.856.839
# ...

# %% [markdown]
# Carga del dataset

# %%
df_ingresos_trim_tele_fija.to_parquet("../Data/Telefonia_fija/Nacional/ingresos_trim_tele_fija.parquet")

# %% [markdown]
# Extraemos el conjunto de datos, que corresponden al acceso de la telefonia fija por provincia

# %%
acceso_tel_fija_provin = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/ACCES-DE-TELEF-FIJA-POR/data.csv/?auth_key=L0hKPyjaBMIJS46l2RPRLaSr6qz7i3EXqwCXTWrq"
df_acceso_tel_fija_provin = funciones.extraer_caonjunto(acceso_tel_fija_provin)
df_acceso_tel_fija_provin
# Out:
#       Año  Trimestre            Provincia Accesos telefonía fija (total)  \
# 0    2022          4         Buenos Aires                      3.128.431
# 1    2022          4      Capital Federal                      1.563.142
# 2    2022          4            Catamarca                         25.083
# 3    2022          4                Chaco                         64.683
# 4    2022          4               Chubut                         54.249
# ..    ...        ...                  ...                            ...
# 859  2014          1           Santa Cruz                         40.625
# 860  2014          1             Santa Fe                        770.361
# 861  2014          1  Santiago del Estero                         70.717
# 862  2014          1     Tierra del Fuego                         32.631
# 863  2014          1              Tucumán                        210.917
#
#     Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# ...

# %% [markdown]
# Carga del dataset

# %%
df_acceso_tel_fija_provin.to_parquet("../Data/Telefonia_fija/Provincia/acceso_tel_fija_provin.parquet")

# %% [markdown]
# Extraemos un cojunto de datos que hace referencia al total de acceso a tecnologia fija

# %%
acceso_total_tel_fija = "http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/TOTAL-NACIO-DE-ACCES-18734/data.csv/?auth_key=L0hKPyjaBMIJS46l2RPRLaSr6qz7i3EXqwCXTWrq"
df_acceso_total_tel_fija = funciones.extraer_caonjunto(acceso_total_tel_fija)
df_acceso_total_tel_fija
# Out:
#      Año  Trimestre Accesos telefonía fija (total)  \
# 0   2014          1                      9.562.231
# 1   2014          2                      9.548.994
# 2   2014          3                      9.613.361
# 3   2014          4                      9.689.752
# 4   2015          1                     10.086.221
# 5   2015          2                      9.991.190
# 6   2015          3                     10.050.617
# 7   2015          4                      9.975.798
# 8   2016          1                     10.239.381
# 9   2016          2                     10.379.749
# 10  2016          3                     10.130.489
# 11  2016          4                     10.260.812
# 12  2017          1                     10.239.381
# 13  2017          2                     10.379.749
# 14  2017          3                     10.130.489
# 15  2017          4                     10.260.812
# 16  2018          1                      9.666.921
# ...

# %% [markdown]
# Caegamos el dataset

# %%
df_acceso_total_tel_fija.to_parquet("../Data/Telefonia_fija/Nacional/acceso_total_tel_fija.parquet")

# %% [markdown]
# Todos los datasets han sido extraidos y cargados para su Etl
